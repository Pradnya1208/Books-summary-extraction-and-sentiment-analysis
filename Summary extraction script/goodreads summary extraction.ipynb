# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup


import os
import urllib.request as request

import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
def find_book_url(page_url):
    with request.urlopen(page_url) as res:
        print(page_url," parsing.....")
        source_data = res.read()
    
    # parse html content
    soup = BeautifulSoup(source_data , 'html.parser')

    goodreads_url = "https://www.goodreads.com/"
    table_class = soup.find_all( class_ = "js-tooltipTrigger tooltipTrigger" )


    for tag in table_class:
        raw_data_ = tag.find("a")
        title_ = str(raw_data_).split(">")[0].split(" title=")[1].replace('"','')
        href_ = goodreads_url + str(raw_data_).split(">")[0].split(" ")[1].split("href=")[1].replace('"','')
        if title_ and href_:
            book_title.append(title_)
            book_link.append(href_)
        else:
            book_title.append("")
            book_link.append("")

# %%
book_title=[]
book_link=[]
for i in range(1,101):
    url_= "https://www.goodreads.com/list/show/1.Best_Books_Ever?page=" + str(i)
    find_book_url(url_)
# Out:
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=1  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=2  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=3  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=4  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=5  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=6  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=7  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=8  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=9  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=10  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=11  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=12  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=13  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=14  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=15  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=16  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=17  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=18  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=19  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=20  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=21  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=22  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=23  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=24  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=25  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=26  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=27  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=28  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=29  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=30  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=31  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=32  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=33  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=34  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=35  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=36  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=37  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=38  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=39  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=40  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=41  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=42  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=43  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=44  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=45  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=46  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=47  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=48  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=49  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=50  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=51  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=52  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=53  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=54  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=55  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=56  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=57  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=58  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=59  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=60  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=61  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=62  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=63  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=64  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=65  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=66  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=67  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=68  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=69  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=70  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=71  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=72  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=73  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=74  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=75  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=76  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=77  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=78  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=79  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=80  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=81  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=82  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=83  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=84  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=85  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=86  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=87  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=88  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=89  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=90  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=91  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=92  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=93  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=94  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=95  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=96  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=97  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=98  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=99  parsing.....
# https://www.goodreads.com/list/show/1.Best_Books_Ever?page=100  parsing.....

# %%
df = pd.DataFrame(list(zip(book_title, book_link)),
               columns =['Title', 'book_url'])

# %%
df.to_csv("Goodreads_books_links.csv")

# %%
def get_summary(book_url):
    with request.urlopen(book_url) as res:
        source_data_ = res.read()
    soup = BeautifulSoup(source_data_ , 'html.parser')
    
    # get summary
    summary_class = soup.find("div", {"id": "description"})
    book_sum= summary_class.text
    
    # get author name
    author_class = soup.find(class_ ="authorName")

    # get bookcover image
    bookcover_class = soup.find(class_ ="bookCoverPrimary")
    img_data = bookcover_class.find_all("a")
    if img_data:
        cover_img_ = str(img_data).split("src=")[1].split("jpg")[0].replace('"','')+"jpg"
    else:
        cover_img_=""
    
    
    
 
   
    book_summaries.append(book_sum.replace("\n","")[:-7])
    book_cover.append(cover_img_)
    author_name.append(author_class.text)

# %%
import pandas as pd
data_= pd.read_csv("Goodreads_books_links.csv")
book_title=[]
book_link=[]
for i,j in zip(data_["Title"].values,data_["book_url"].values):
    book_title.append(i)
    book_link.append(j)

# %%
book_summaries =[]
book_cover=[]
author_name=[]

#Do the batch scraping to avoid server side errors

for count,link in enumerate(book_link[1000:1100],1000):
    #print(count," :",link," collecting data....")
    get_summary(link)

# %%
books_df = pd.DataFrame(list(zip(book_title[1000:1100],author_name, book_summaries, book_cover, book_link[1000:1100])),
               columns =['title', 'author','summary','bookcover','book_url'])

# %%
books_df.to_csv("goodreads_book_summaries_13.csv")

# %%
# merging all csv files
csv_files= ['goodreads_book_summaries_1.csv','goodreads_book_summaries_2.csv', 'goodreads_book_summaries_3.csv',
           'goodreads_book_summaries_4.csv','goodreads_book_summaries_5.csv', 'goodreads_book_summaries_6.csv',
           'goodreads_book_summaries_7.csv','goodreads_book_summaries_8.csv', 'goodreads_book_summaries_9.csv',
           'goodreads_book_summaries_10.csv','goodreads_book_summaries_11.csv', 'goodreads_book_summaries_12.csv', 'goodreads_book_summaries_13.csv']
df = pd.concat(
    map(pd.read_csv, csv_files), ignore_index=True)
df

# %%
df.head()
# Out:
#                                        title           author  \
# 0                           The Hunger Games  Suzanne Collins
# 1  Harry Potter and the Order of the Phoenix     J.K. Rowling
# 2                      To Kill a Mockingbird       Harper Lee
# 3                        Pride and Prejudice      Jane Austen
# 4                             The Book Thief     Markus Zusak
#
#                                              summary  \
# 0  Could you survive on your own in the wild, wit...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  Alternate cover edition of ISBN 9780679783268S...
# 4  Librarian's note: An alternate cover edition c...
#
#                                            bookcover  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...
# 1  https://i.gr-assets.com/images/S/compressed.ph...
# 2  https://i.gr-assets.com/images/S/compressed.ph...
# 3  https://i.gr-assets.com/images/S/compressed.ph...
# 4  https://i.gr-assets.com/images/S/compressed.ph...
#
#                                             book_url
# 0  https://www.goodreads.com//book/show/2767052-t...
# 1  https://www.goodreads.com//book/show/2.Harry_P...
# 2  https://www.goodreads.com//book/show/2657.To_K...
# 3  https://www.goodreads.com//book/show/1885.Prid...
# 4  https://www.goodreads.com//book/show/19063.The...

# %%
df.to_csv("goodreads_book_summaries.csv")
